# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
sns.histplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
df.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap='viridis',cbar=False)
# Out:
# <AxesSubplot:>

# %%
df.drop('id', axis=1, inplace=True)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()['price'].drop('price').sort_values(ascending=False)

# %%
plt.figure(figsize=(20,10))
sns.barplot(corr.index, corr.values)
# Out:
# <AxesSubplot:>

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2007       35
#         ...
# 1948        1
# 1954        1
# 1951        1
# 1944        1
# 1959        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
sns.scatterplot('yr_renovated','price', data=df)
# Out:
# <AxesSubplot:xlabel='yr_renovated', ylabel='price'>

# %%
df.drop(['yr_renovated','zipcode'],axis=1,inplace=True)

# %%
df.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#        lat     long  sqft_living15  sqft_lot15
# ...

# %%
df['month'] = df['date'].apply(lambda x: x.month)
df['year'] = df['date'].apply(lambda x: x.year)
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#        lat     long  sqft_living15  sqft_lot15  month  year
# ...

# %%
df.drop('date',axis=1,inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.scatterplot('year','price', data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
plt.figure(figsize=(20,10))
sns.scatterplot('month','price', data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['price'],axis=1)
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# -109278712.15894681

# %%
reg.coef_
# Out:
# array([-3.61528225e+04,  3.94045722e+04,  1.09056486e+02,  1.36724625e-01,
#         7.17493548e+03,  5.60481175e+05,  4.83743011e+04,  3.17755578e+04,
#         9.86878659e+04,  7.11473418e+01,  3.79091446e+01, -2.58893753e+03,
#         5.60126438e+05, -1.17020842e+05,  2.75376196e+01, -3.60045728e-01,
#         1.23964992e+03,  3.60931345e+04])

# %%
pd.DataFrame(reg.coef_,X.columns,columns=['coeff'])
# Out:
#                        coeff
# bedrooms       -36152.822492
# bathrooms       39404.572239
# sqft_living       109.056486
# sqft_lot            0.136725
# floors           7174.935477
# waterfront     560481.175210
# view            48374.301137
# condition       31775.557837
# grade           98687.865934
# sqft_above         71.147342
# sqft_basement      37.909145
# yr_built        -2588.937535
# lat            560126.438423
# long          -117020.841704
# sqft_living15      27.537620
# sqft_lot15         -0.360046
# month            1239.649919
# year            36093.134465

# %%
predictions = reg.predict(X_test)
predictions
# Out:
# array([536749.26469964, 668561.61744678, 550121.85357034, ...,
#        592769.1091623 , 149239.10231017, 983915.71491307])

# %%
sns.scatterplot(y_test,predictions)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
sns.distplot((y_test-predictions))
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 126268.5310741552

# %%
mean_squared_error(y_test,predictions)
# Out:
# 41476693257.56571

# %%
one_house = X_test.iloc[0]
reg.predict(one_house.values.reshape(-1,18))[0]
# Out:
# 536749.264699623

# %%
y_test.iloc[0]
# Out:
# 349950.0
